# %%
## Import relevant libraries
import pandas as pd
import numpy as np
from sklearn.externals import joblib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-c65b2b18ba11> in <module>()
#       1 ## Import relevant libraries
# ----> 2 import pandas as pd
#       3 import numpy as np
#       4 from sklearn.externals import joblib
#
# ModuleNotFoundError: No module named 'pandas'

# %%
resolution_codes = pd.read_csv("service_requests_Train-test_set.csv")

# %%
error_codes_pivoted = pd.read_csv("error_codes_pivoted_final.csv")

# %%
# !pip install sklearn-pandas
# Out:
#   File "<ipython-input-90-ac274e858666>", line 2
#     import sklearn-pandas
#                   ^
# SyntaxError: invalid syntax

# %%
# Import stopwords with scikit-learn
from sklearn.feature_extraction import text
stop = text.ENGLISH_STOP_WORDS
stopwords = r'\b(?:{})\b'.format('|'.join(stop))

remove_words = ['imagenonenonenone', '^image', 'cst', 'cd']
remove_words = r'\b(?:{})\b'.format('|'.join(remove_words))

huge_string = resolution_codes.symptom.str.replace('[^\w\s]','').str.lower().str.replace(stopwords, '').str.replace('\d+', '').str.replace(remove_words, '').str.cat(sep=' ')

# %%
resolution_codes_samples = resolution_codes[0:10]

# %%
import requests
import ast

# %%
execution_url = 'https://predix-analytics-catalog-release.run.aws-usw02-pr.ice.predix.io/api/v1/catalog/analytics/f7327915-7f5c-417f-b798-cae17771715a/execution'
headers = {
    'Content-Type': 'application/json',
    'Authorization': 'Bearer eyJhbGciOiJSUzI1NiIsImtpZCI6IlU5V0VXIiwidHlwIjoiSldUIn0.....Sou1y4Yqh0jaTA85-wc88h51T94P0yA6bJTANRrAkYOadLuSFf_rj7KQI3V5izN_LqGx8HwE4xskIItOThvZLl-qEtNBxCVlp7rcmm5a83IzayF-C6cpTqAqsS469lsxakda6W8fYPOzmO0nQuq3k0WCsoJMvnXdu05nGgwd-ws8aCVIl9tpnYd9EAALcyHxnLnpnqgvizixeaO2_7uXfDMKhcSwnIJaw9rC39EQ9NxLFtOvQ4ZD2zkBeK5Hvv-hkATU6-OswHu6ZbLPjfyCGRHksm4UlWJhifGKJpalx6BRxnzbtySnEs5Lk3NukDhYBvHXw2P9hBqnebcs0ovj0w',
    'Predix-Zone-Id': '7d4c4e3f-b5a5-41d8-918d-9b33f8b4dbb2',
}
payload = {
    'input_test': resolution_codes_samples.symptom[1]
}

# %%
r = requests.post(execution_url, headers=headers, json=payload)

# %%
def request_function(j):
    payload = {'input_test': j}
    result = requests.post(execution_url, headers=headers, json=payload)
    return ast.literal_eval(result.json()['result'])

resolution_codes_samples['cleaned_column'] = resolution_codes_samples['symptom'].apply(request_function)
# Out:
# /anaconda3/envs/datascience/lib/python3.6/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
from sklearn.preprocessing import MultiLabelBinarizer

mlb = MultiLabelBinarizer()
resolution_codes_samples_pivoted = resolution_codes_samples.join(pd.DataFrame(mlb.fit_transform(resolution_codes_samples.pop('cleaned_column')),
                          columns=mlb.classes_,
                          index=resolution_codes_samples.index))

# %%
resolution_codes_samples_pivoted
# Out:
#             sr_id      Created_Date                   Resolution_Code  \
# 0  1-200016966951  10/27/2016 12:51                         Reset_UPS
# 1  1-202188076151   12/12/2016 0:05           Troubleshoot_HEMIT_TANK
# 2  1-186899060621   3/21/2016 20:55       No structural problem found
# 3       360154703   10/18/2012 0:00       No structural problem found
# 4  1-174918638991   7/31/2015 21:25              Configure_ConnectPro
# 5  1-205402405831   2/24/2017 18:26           Troubleshoot_HEMIT_TANK
# 6  1-184683709341   2/10/2016 14:48       No structural problem found
# 7  1-182969359501   1/13/2016 23:59       Reset_the_system_time_clock
# 8  1-200863773491  11/15/2016 17:28          Adjust_gantry_tilt_speed
# 9  1-182424492456    1/6/2016 23:16  Troubleshoot_GANTRY_TOUCH_SENSOR
#
#                                              symptom  0600cst experienced  \
# 0          UPS fails to come up Image:NONE-NONE-NONE                    0
# ...

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics

# define a function that accepts a vectorizer and calculates the accuracy
def tokenize_test(vect):
    
    # create document-term matrices using the vectorizer
    X_train_dtm = vect.fit_transform(X_train)
    X_test_dtm = vect.transform(X_test)
    
    # print the number of features that were generated
    print('Features: ', X_train_dtm.shape[1])
    
    # use Multinomial Naive Bayes to predict the star rating
    nb = MultinomialNB()
    nb.fit(X_train_dtm, y_train)
    y_pred_class = nb.predict(X_test_dtm)
    
    # print the accuracy of its predictions
    print('Accuracy: ', metrics.accuracy_score(y_test, y_pred_class))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-854338dcf9c6> in <module>()
# ----> 1 from sklearn.naive_bayes import MultinomialNB
#       2 from sklearn import metrics
#       3
#       4 # define a function that accepts a vectorizer and calculates the accuracy
#       5 def tokenize_test(vect):
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# create a document-term matrix (minus stop words) using TfidfVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

vect = TfidfVectorizer(stop_words='english')
X = vect.fit_transform(resolution_codes_samples.symptom)

count_vect_df = pd.DataFrame(X.todense(), columns=vect.get_feature_names())
count_vect_df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-5eab40ca21b6> in <module>()
#       1 # create a document-term matrix (minus stop words) using TfidfVectorizer
# ----> 2 from sklearn.feature_extraction.text import TfidfVectorizer
#       3
#       4 vect = TfidfVectorizer(stop_words='english')
#       5 X = vect.fit_transform(resolution_codes_samples.symptom)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# create a list of all of the features
features = vect.get_feature_names()
len(features)
features
# Out:
# ['0582',
#  '0600cst',
#  '0700cst',
#  '0900cst',
#  '10',
#  '12',
#  '1425',
#  '15',
#  '16',
#  '181491307381',
#  '19th',
#  '20',
#  '22',
#  '2339',
#  '2449',
#  '29',
#  '30',
#  '300ma',
#  '30936',
#  '31109',
#  '3502',
#  '360',
#  '4848665804',
#  '4888',
#  '575',
#  '5ms',
#  '649',
#  '7022',
#  '740',
#  '7888',
#  '80kv',
#  'a1',
#  'abdomen',
#  'amy',
#  'angle',
#  'angled',
#  'appreciate',
#  'arrow',
#  'artifact',
#  'artifacts',
#  'attempting',
#  'attention',
#  'axial',
#  'battery',
#  'biopsy',
#  'blown',
#  'breaker',
#  'broke',
#  'broken',
#  'brought',
#  'buttons',
#  'bypass',
#  'called',
#  'cals',
#  'cardboard',
#  'caren',
#  'caught',
#  'cd',
#  'certificate',
#  'change',
#  'changes',
#  'check',
#  'class',
#  'clicking',
#  'come',
#  'coming',
#  'completed',
#  'compliance',
#  'connect',
#  'contact',
#  'cool',
#  'correct',
#  'corrugated',
#  'cover',
#  'cradle',
#  'ct',
#  'curved',
#  'customer',
#  'dark',
# ...

# %%
import numpy as np

def summarize():
    
    # choose a random review that is at least 400 characters
    review_length = 0
    while review_length < 400:
        review_id = np.random.randint(0, resolution_codes_samples.shape[0])
        review_text = resolution_codes_samples.loc[review_id, 'symptom']
        review_length = len(review_text)
    
    # create a list of all unique words in the review (minus stop words) using CountVectorizer
    vect = CountVectorizer(stop_words='english')
    vect.fit([review_text])
    unique_words = vect.get_feature_names()
    
    # create a dictionary of words and their TF-IDF scores
    word_scores = {}
    for word in unique_words:
        word_scores[word] = dtm[review_id, features.index(word)]
    
    # print words with the top 5 TF-IDF scores
    print('TOP SCORING WORDS:')
    top_scores = sorted(word_scores.items(), key=lambda x: x[1], reverse=True)[0:5]
    for word, score in top_scores:
        print(word)
    
    # print 5 random words (for comparison)
    print('\n' + 'RANDOM WORDS:')
    random_words = np.random.choice(list(word_scores.keys()), size=5, replace=False)
    for word in random_words:
        print(word)
    
    # print the review
    print('\n' + review_text)

# %%
summarize()
# Out:
# TOP SCORING WORDS:
# did
# yesterday
# 10
# 1425
# 575
#
# RANDOM WORDS:
# 10
# started
# mon
# stopped
# warmup
#
# CD Mon 10/10 0900CST Please check error logs  machine is down. we had a power outage yesterday ... it worked yesterday I did my warmup and phantom and it was fine. When pt was brought in for biopsy the scanner was making a grinding noise. It then stopped scanning  I did another restart and no go . . . . even did a hard shutdown and still nothing.  please call me at 575 649 7888.   thank you this started at about 1425 Image:NONE-NONE-NONE Please check error logs  machine is down. we had a power outage yesterday ... it worked yesterday I did my warmup and phantom and it was fine. When pt was brought in for biopsy the scanner was making a grinding noise. It then stopped scanning  I did another restart and no go . . . . even did a hard shutdown and still nothing.  please call me at 575 649 7888.   thank you this started at about 1425 Image:NONE-NONE-NONE

# %%
resolution_codes_samples = resolution_codes
y_pred_class = pd.DataFrame()

# %%
X = resolution_codes_samples.symptom
y = resolution_codes_samples.Resolution_Code

# split X and y into training and testing sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
from sklearn.feature_extraction import text
## Import relevant libraries
import pandas as pd
import numpy as np

vect = CountVectorizer(stop_words='english', binary=True)
X = vect.fit_transform(X_train)
count_vect_df = pd.DataFrame(X.todense(), columns=vect.get_feature_names())
pd.concat([X_train, count_vect_df], axis=1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-fb425df73939> in <module>()
# ----> 1 from sklearn.model_selection import train_test_split
#       2 from sklearn.feature_extraction.text import CountVectorizer
#       3 from sklearn.model_selection import train_test_split
#       4 from sklearn.naive_bayes import MultinomialNB
#       5 from sklearn import metrics
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics

# define a function that accepts a vectorizer and calculates the accuracy
def tokenize_test(vect):
    
    # create document-term matrices using the vectorizer
    X_train_dtm = vect.fit_transform(X_train)
    X_test_dtm = vect.transform(X_test)
    
    # print the number of features that were generated
    print('Features: ', X_train_dtm.shape[1])
    
    
    
    # use Multinomial Naive Bayes to predict the star rating
    nb = MultinomialNB()
    nb.fit(X_train_dtm, y_train)
    y_pred_class = nb.predict(X_test_dtm)
    
    # print the accuracy of its predictions
    print('Accuracy: ', metrics.accuracy_score(y_test, y_pred_class))
    return(y_pred_class)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-501dc58e6db4> in <module>()
# ----> 1 from sklearn.naive_bayes import MultinomialNB
#       2 from sklearn import metrics
#       3
#       4 # define a function that accepts a vectorizer and calculates the accuracy
#       5 def tokenize_test(vect):
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# use CountVectorizer with default parameters
vect = CountVectorizer()
pred = tokenize_test(vect)
# Out:
# Features:  5928
# Accuracy:  0.36104513064133015

# %%
# tune TfidfVectorizer for better results
vect = TfidfVectorizer(norm=None)
tokenize_test(vect)
# Out:
# Features:  5928
# Accuracy:  0.3996437054631829
# array(['Reset_UPS', 'Clean_or_adjust_mylar_scan_window',
#        'Troubleshoot_X_RAY_TUBE', ...,
#        'Clean_or_adjust_mylar_scan_window',
#        'Cycle_the_Gantry_and_table_power_or_Reset_scan_hardware',
#        'No structural problem found'], dtype='<U55')

# %%
df1 = pd.DataFrame(pred).reset_index()
df2 = pd.DataFrame(y_test).reset_index()
df1 = df1[0]
df2 = df2["Resolution_Code"]
symptom = pd.DataFrame(resolution_codes.symptom
final_result = pd.concat([symptom, df1, df2], axis = 1)

# %%
error_codes_num = pd.read_csv("grouped_by_count.csv")

# %%
## Find each resolution code and the number of error codes on average 
error_codes_num_merged = pd.merge(resolution_codes, error_codes_num, 'left')

# %%
error_codes_num_merged
# Out:
#                sr_id      Created_Date  \
# 0     1-200016966951  10/27/2016 12:51
# 1     1-202188076151   12/12/2016 0:05
# 2     1-186899060621   3/21/2016 20:55
# 3          360154703   10/18/2012 0:00
# 4     1-174918638991   7/31/2015 21:25
# 5     1-205402405831   2/24/2017 18:26
# 6     1-184683709341   2/10/2016 14:48
# 7     1-182969359501   1/13/2016 23:59
# 8     1-200863773491  11/15/2016 17:28
# 9     1-182424492456    1/6/2016 23:16
# 10    1-173167991671   6/23/2015 20:31
# 11    1-174131477251   7/14/2015 15:52
# 12    1-167954054371    2/20/2015 2:14
# 13    1-193333619846   6/24/2016 15:02
# 14    1-175014117191    8/3/2015 18:22
# 15    1-198185074691    9/22/2016 4:29
# 16    1-199216051981   10/8/2016 15:25
# 17    1-181775037201  12/21/2015 17:21
# 18    1-159456975421  11/15/2014 23:48
# 19    1-195427162381   7/26/2016 12:20
# 20    1-192975792937   6/15/2016 14:44
# 21    1-189080078901   5/20/2016 17:21
# 22    1-197841371701   9/14/2016 15:44
# ...

# %%
error_codes_num_merged.to_csv("resolution_codes_and_error_code_num.csv")

# %%
error_codes_last_five = pd.read_csv("error_codes_lastfive.csv")

# %%
error_codes_last_fiveer
# Out:
#                 sr_id  error_codes  log_timestamp
# 0      1-153073514705    200002392   24/8/14 5:08
# 1      1-153073514705    200002395   24/8/14 5:08
# 2      1-153073514705    200002348   24/8/14 5:09
# 3      1-153073514705    200002396   24/8/14 5:09
# 4      1-153073514705    200501502   24/8/14 5:09
# 5      1-153565927726    200002348   6/9/14 17:33
# 6      1-153565927726    200002396   6/9/14 17:33
# 7      1-153565927726    200002396   6/9/14 17:33
# 8      1-153565927726    200501502   6/9/14 17:33
# 9      1-153565927726    200501502   6/9/14 17:33
# 10     1-153697027976    200002348   7/9/14 14:20
# 11     1-153697027976    200002396   7/9/14 14:20
# 12     1-153697027976    200002396   7/9/14 14:20
# 13     1-153697027976    200501502   7/9/14 14:20
# 14     1-153697027976    200501502   7/9/14 14:20
# 15     1-172369391861    210000454   2/6/15 14:26
# 16     1-172369391861    200109109   2/6/15 14:59
# 17     1-172369391861       245278   2/6/15 15:00
# ...

# %%
a = error_codes_last_five.groupby('sr_id').count()
a2 = a[a.error_codes < 5]
# Out:
#                 error_codes  log_timestamp
# sr_id
# 1-175764106611            4              4
# 1-176110242209            2              2
# 1-177751352706            4              4
# 1-181402297515            4              4
# 1-181661248850            4              4
# 1-182993622251            4              4
# 1-183914208491            4              4
# 1-184065652151            4              4
# 1-184119887025            4              4
# 1-184126200281            4              4
# 1-185065687251            1              1
# 1-185334239501            4              4
# 1-186425484970            2              2
# 1-186442219781            4              4
# 1-187719550754            4              4
# 1-187788014231            1              1
# 1-187878315661            3              3
# 1-187947562761            4              4
# 1-188785276341            4              4
# 1-188843236530            4              4
# 1-188962733482            4              4
# ...

# %%
resolution_codes[resolution_codes['sr_id'] == "1-203958801505"]
# Out:
#               sr_id    Created_Date          Resolution_Code  \
# 666  1-203958801505  1/23/2017 6:36  Troubleshoot_HEMIT_TANK
#
#                                     symptom
# 666  CD Mon 1/23 0800CST  cannot scan axcel
